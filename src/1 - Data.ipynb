# %% [markdown]
# ## Set up

# %%
from helper_functions import load_data

# %%
train_data = load_data('2023-01-01', '2023-12-31')
train_data.to_csv('train_data.csv')
# Out:
# Loading bid data
# Loaded bid data
#                           datetime tickersymbol  quantity  depth
# 0       2023-01-03 09:00:00.255488    VN30F2301      1872      1
# 1       2023-01-03 09:00:04.531564    VN30F2301      1939      1
# 2       2023-01-03 09:00:04.909676    VN30F2301       147      1
# 3       2023-01-03 09:00:04.909676    VN30F2301        50      2
# 4       2023-01-03 09:00:04.909676    VN30F2301         8      3
# ...                            ...          ...       ...    ...
# 2858852 2023-12-29 14:29:54.320223    VN30F2401        90      2
# 2858853 2023-12-29 14:29:54.320223    VN30F2401       100      3
# 2858854 2023-12-29 14:29:57.149751    VN30F2401        11      1
# 2858855 2023-12-29 14:29:57.149751    VN30F2401        15      2
# 2858856 2023-12-29 14:29:57.149751    VN30F2401        61      3
#
# [2858857 rows x 4 columns]
# ...

# %%
test_data = load_data('2024-01-01', '2024-11-30')
test_data.to_csv('test_data.csv')
# Out:
# Loading bid data
# Loaded bid data
#                           datetime tickersymbol  quantity  depth
# 0       2024-01-02 09:00:00.384371    VN30F2401      1422      1
# 1       2024-01-02 09:00:03.177111    VN30F2401         4      3
# 2       2024-01-02 09:00:08.022892    VN30F2401        40      1
# 3       2024-01-02 09:00:08.022892    VN30F2401         3      2
# 4       2024-01-02 09:00:08.022892    VN30F2401         1      3
# ...                            ...          ...       ...    ...
# 2952253 2024-11-29 14:29:55.335008    VN30F2412         1      1
# 2952254 2024-11-29 14:29:55.335008    VN30F2412       140      2
# 2952255 2024-11-29 14:29:59.240617    VN30F2412        15      2
# 2952256 2024-11-29 14:29:59.240617    VN30F2412        33      1
# 2952257 2024-11-29 14:29:59.240617    VN30F2412        12      3
#
# [2952258 rows x 4 columns]
# ...
